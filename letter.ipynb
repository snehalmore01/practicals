# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelBinarizer
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/letter-recognition/letter-recognition.data"
col_names = ["letter"] + [f"feat_{i}" for i in range(16)]
data = pd.read_csv(url, header=None, names=col_names)

# %%
X = data.drop("letter", axis=1).values
y = data["letter"].values

# %%
encoder = LabelBinarizer()
Y = encoder.fit_transform(y)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(16,)),
    Dense(64, activation='relu'),
    Dense(26, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
history = model.fit(X_train, Y_train, epochs=25, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5875 - loss: 1.5124 - val_accuracy: 0.7544 - val_loss: 0.8522
# Epoch 2/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7953 - loss: 0.7073 - val_accuracy: 0.8300 - val_loss: 0.5984
# Epoch 3/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8453 - loss: 0.5274 - val_accuracy: 0.8612 - val_loss: 0.4845
# Epoch 4/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8761 - loss: 0.4236 - val_accuracy: 0.8813 - val_loss: 0.4047
# Epoch 5/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8956 - loss: 0.3524 - val_accuracy: 0.8956 - val_loss: 0.3300
# Epoch 6/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9106 - loss: 0.3005 - val_accuracy: 0.9075 - val_loss: 0.2905
# Epoch 7/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9205 - loss: 0.2617 - val_accuracy: 0.9281 - val_loss: 0.2615
# Epoch 8/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9280 - loss: 0.2338 - val_accuracy: 0.9269 - val_loss: 0.2427
# Epoch 9/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9381 - loss: 0.2056 - val_accuracy: 0.9325 - val_loss: 0.2291
# Epoch 10/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9428 - loss: 0.1858 - val_accuracy: 0.9419 - val_loss: 0.2091
# Epoch 11/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9482 - loss: 0.1685 - val_accuracy: 0.9400 - val_loss: 0.1979
# Epoch 12/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9524 - loss: 0.1543 - val_accuracy: 0.9381 - val_loss: 0.1980
# Epoch 13/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9575 - loss: 0.1426 - val_accuracy: 0.9400 - val_loss: 0.1821
# Epoch 14/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9583 - loss: 0.1318 - val_accuracy: 0.9475 - val_loss: 0.1684
# Epoch 15/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9627 - loss: 0.1199 - val_accuracy: 0.9469 - val_loss: 0.1906
# Epoch 16/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9663 - loss: 0.1138 - val_accuracy: 0.9544 - val_loss: 0.1577
# Epoch 17/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9688 - loss: 0.1042 - val_accuracy: 0.9550 - val_loss: 0.1452
# Epoch 18/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9676 - loss: 0.0987 - val_accuracy: 0.9463 - val_loss: 0.1538
# Epoch 19/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9708 - loss: 0.0914 - val_accuracy: 0.9569 - val_loss: 0.1439
# Epoch 20/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9748 - loss: 0.0843 - val_accuracy: 0.9556 - val_loss: 0.1439
# Epoch 21/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9749 - loss: 0.0805 - val_accuracy: 0.9500 - val_loss: 0.1611
# Epoch 22/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9769 - loss: 0.0766 - val_accuracy: 0.9531 - val_loss: 0.1413
# Epoch 23/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9771 - loss: 0.0722 - val_accuracy: 0.9538 - val_loss: 0.1395
# Epoch 24/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9802 - loss: 0.0652 - val_accuracy: 0.9563 - val_loss: 0.1404
# Epoch 25/25
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9815 - loss: 0.0625 - val_accuracy: 0.9550 - val_loss: 0.1389

# %%
test_loss, test_acc = model.evaluate(X_test, Y_test)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9532 - loss: 0.1451
# Test Accuracy: 0.9532
